# %%
import pandas as pd

# Configurar pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Ruta al archivo .xlsm
file_path = r'C:\Users\soled\Desktop\Ecovidrio\files\ecovidrio\excel\FDE_Ventas_2023 MAHOU SA 300524 FINAL.xlsm'

# Leer el archivo .xlsm
xls = pd.ExcelFile(file_path, engine='openpyxl')

# Mostrar los nombres de las hojas disponibles
print("Hojas disponibles:", xls.sheet_names)

# Leer y mostrar las primeras 10 filas de la hoja 'FDE'
sheet_name = 'Principal- Auxiliar'
df_fde = pd.read_excel(file_path, sheet_name=sheet_name, engine='openpyxl')
print(f"Hoja: {sheet_name}")
display(df_fde)
# Out:
# Hojas disponibles: ['Índice', 'FDE', 'Tarifa', 'Principal- Auxiliar', 'Errores', 'Material x Subtipo envase', 'Categorías', 'Sectores', 'Subsectores', 'Tipo envase RPP', 'Subtipo envase', 'Opciones MM', 'Color', 'Material', 'Cat x Tipo RPP x Mat', 'Material x Subtipo', 'Cat x Tipo RPP x Subtipo', 'Regla SUP', 'Pesos medios x Sector']
# Hoja: Principal- Auxiliar
#   Tipo elemento  Unnamed: 1                          Cat  \
# 0     Principal         NaN  Bebidas HORECA reutilizable
# 1      Auxiliar         NaN  Bebidas HORECA reutilizable
# 2           NaN         NaN  Bebidas HORECA reutilizable
# 3           NaN         NaN  Bebidas HORECA reutilizable
# 4           NaN         NaN  Bebidas HORECA reutilizable
# 5           NaN         NaN  Bebidas HORECA reutilizable
# 6           NaN         NaN  Bebidas HORECA reutilizable
#
#                                              Subtipo  \
# 0                                  Barril / depósito
# ...
